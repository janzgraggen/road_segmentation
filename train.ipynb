# %%
from train import main
from hydra import compose, initialize

# %%
initialize(version_base=None, config_path="src/configs")

# %%
cfg = compose(config_name="resnet.yaml", return_hydra_config=True)
main(cfg)
