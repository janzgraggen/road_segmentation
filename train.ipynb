# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !cp -r gdrive/MyDrive/ml-project-2-team-kangaroos/* .

# %%
# !pip install hydra-core

# %%
from train import main
from submit import main as submit
from hydra import compose, initialize

# %%
initialize(version_base=None, config_path="src/configs")

# %%
cfg = compose(config_name="mobilenetv3.yaml", return_hydra_config=True)
main(cfg)

# %%
cfg = compose(config_name="submit.yaml", return_hydra_config=True)
submit(cfg)
